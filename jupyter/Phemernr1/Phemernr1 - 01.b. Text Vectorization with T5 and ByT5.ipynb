# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(1, '../..')

from library.vectorization import sbert_vectorize_and_save
# Out:
# /media/storage/Work/DataScience/.venv/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-64505387a195> in <module>
#       4 sys.path.insert(1, '../..')
#       5
# ----> 6 from library.vectorization import sbert_vectorize_and_save
#
# /media/storage/Work/DataScience/jupyter/Phemernr1_tvt/../../library/vectorization.py in <module>
#       4 import numpy as np
#       5 from gensim import corpora, models
# ----> 6 from sentence_transformers import SentenceTransformer
#       7 from typing import List
# ...

# %%
phemernr = pd.read_csv("../../data/processed/phemernr1_dataset_with_tvt.csv", lineterminator="\n")
phemernr.head()

# %%
texts = phemernr["tweet_text"].tolist()

# %%
sbert_vec = sbert_vectorize_and_save(texts,
                                     "t5-base",
                                     "./data/processed/vectors/Phemernr1_T5_vectors.txt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8e69836888b5> in <module>
# ----> 1 sbert_vec = sbert_vectorize_and_save(texts,
#       2                                      "t5-base",
#       3                                      "./data/processed/vectors/Phemernr1_T5_vectors.txt")
#
# NameError: name 'sbert_vectorize_and_save' is not defined

# %%
from transformers import T5Model, T5Tokenizer

word_emb_model = T5Model.from_pretrained("t5-base")
tok = T5Tokenizer.from_pretrained("t5-base")

enc = tok("some text", return_tensors="pt")

# forward pass through encoder only
output = word_emb_model.encoder(
    input_ids=enc["input_ids"], 
    attention_mask=enc["attention_mask"], 
    return_dict=True
)
# get the final hidden states
emb = output.last_hidden_state
emb.shape
# Out:
# Downloading:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# torch.Size([1, 3, 768])

# %%
from sentence_transformers.models import Pooling
from sentence_transformers import SentenceTransformer

pooling_model = Pooling(emb.shape[1:])

result = pooling_model.forward(emb)
result.shape
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-69a9c0e016dc> in <module>
#       1 from sentence_transformers.models import Pooling
# ----> 2 from sentence_transformers import SentenceTransformer
#       3
#       4 pooling_model = Pooling(emb.shape[1:])
#       5
#
# /media/storage/Work/DataScience/.venv/lib/python3.8/site-packages/sentence_transformers/__init__.py in <module>
#       1 __version__ = "1.0.4"
#       2 __DOWNLOAD_SERVER__ = 'http://sbert.net/models/'
# ----> 3 from .datasets import SentencesDataset, ParallelSentencesDataset
#       4 from .LoggingHandler import LoggingHandler
#       5 from .SentenceTransformer import SentenceTransformer
#
# /media/storage/Work/DataScience/.venv/lib/python3.8/site-packages/sentence_transformers/datasets/__init__.py in <module>
# ----> 1 from .ParallelSentencesDataset import ParallelSentencesDataset
# ...
